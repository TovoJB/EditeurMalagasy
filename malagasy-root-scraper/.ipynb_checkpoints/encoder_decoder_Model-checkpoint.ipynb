# %% [markdown]
# # 🧠 Malagasy Morpheme Segmentation: Root Tagging Seq2Seq Model
#
# Ce notebook implémente un modèle **Seq2Seq** au niveau des caractères capable de segmente les mots ET d'identifier la racine en l'entourant de crochets (ex: `miaboabo` ➔ `mi|[abo]|[abo]`).

# %%
import tensorflow as tf

gpus = tf.config.list_physical_devices('GPU')
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)
    print(f"✅ GPU prêt : {[g.name for g in gpus]}")
else:
    print("⚠️  Aucun GPU — CPU utilisé.")
# Out:
# ⚠️  Aucun GPU — CPU utilisé.

# %%
model.fit(
    [X_train, d_in_train], d_out_train,
    batch_size=256,   # ← augmenté de 64 à 256 pour mieux saturer le GPU
    epochs=100,
    validation_data=([X_test, d_in_test], d_out_test)
)

# %%
import pandas as pd
import pandas as pd
import numpy as np
import json
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
import pickle
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Input

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.21.0

# %% [markdown]
# ## 🏷️ 1. Chargement et Marquage des Racines (Target Tagging)

# %%
# Charger les deux datasets
df_morphs = pd.read_csv('malagasy_training_data.csv')
df_fused = pd.read_csv('malagasy_data_FINAL.csv')

# Fusionner pour avoir l'info de la racine pour chaque mot
df = pd.merge(df_morphs, df_fused[['word', 'root']], on='word', how='left').drop_duplicates()

def format_target_with_root(row):
    morphs = json.loads(row['morphemes'])
    root = str(row['root'])
    
    tagged_morphs = []
    for m in morphs:
        # Si le morphème est identique à la racine, on l'entoure de crochets
        if m == root:
            tagged_morphs.append(f"[{m}]")
        else:
            tagged_morphs.append(m)
            
    return "|".join(tagged_morphs)

df['target'] = df.apply(format_target_with_root, axis=1)
df['input'] = df['word']

print("Aperçu des données avec racines marquées :")
display(df[['input', 'target']].head(15))
# Out:
# Aperçu des données avec racines marquées :
#               input               target
# 0           ababoka           a|[baboka]
# 1           ababoke           a|[baboke]
# 2             ababy             a|[baby]
# 3              abae              a|[bae]
# 4           abafoka           a|[bafoka]
# 5             abaha             a|[baha]
# 6           abahana           a|[bahana]
# 7           abaibay           a|[baibay]
# 8       abaikabaika        a|baika|baika
# 9            abaiko            a|[baiko]
# 10         abailoka          a|[bailoka]
# 11          abaingo           a|[baingo]
# 12  abaingobaingoka  a|baingoka|baingoka
# 13            abaka             a|[baka]
# 14        abalabala          a|bala|bala

# %%
def create_vocab(texts):
    vocab = set("".join(texts))
    char2idx = {char: i + 2 for i, char in enumerate(sorted(list(vocab)))}
    char2idx['<PAD>'] = 0
    char2idx['<SOS>'] = 1
    char2idx['<EOS>'] = len(char2idx)
    idx2char = {i: char for char, i in char2idx.items()}
    return char2idx, idx2char

char2idx, idx2char = create_vocab(df['input'].tolist() + df['target'].tolist())

VOCAB_SIZE = len(char2idx)
MAX_LEN_IN = df['input'].apply(len).max()
MAX_LEN_OUT = df['target'].apply(len).max() + 2

print(f"Vocab Size: {VOCAB_SIZE}")
# Out:
# Vocab Size: 29

# %%
def vectorize(texts, char2idx, max_len, add_sos=False, add_eos=False):
    seqs = []
    for text in texts:
        seq = []
        if add_sos: seq.append(char2idx['<SOS>'])
        for char in str(text):
            seq.append(char2idx.get(char, 0))
        if add_eos: seq.append(char2idx['<EOS>'])
        seqs.append(seq)
    return pad_sequences(seqs, maxlen=max_len, padding='post')

X = vectorize(df['input'].tolist(), char2idx, MAX_LEN_IN)
dec_in = vectorize(df['target'].tolist(), char2idx, MAX_LEN_OUT, add_sos=True)
dec_out = vectorize(df['target'].tolist(), char2idx, MAX_LEN_OUT, add_eos=True)

X_train, X_test, d_in_train, d_in_test, d_out_train, d_out_test = train_test_split(
    X, dec_in, dec_out, test_size=0.1, random_state=42
)

# %% [markdown]
# ## 🏗️ 2. Architecture Seq2Seq

# %%
LATENT_DIM = 256
EMBEDDING_DIM = 64

# ENCODER
encoder_inputs = Input(shape=(MAX_LEN_IN,))
enc_emb = Embedding(VOCAB_SIZE, EMBEDDING_DIM, mask_zero=True)(encoder_inputs)
_, sh, sc = LSTM(LATENT_DIM, return_state=True)(enc_emb)
encoder_states = [sh, sc]

# DECODER
decoder_inputs = Input(shape=(None,))
dec_emb_layer = Embedding(VOCAB_SIZE, EMBEDDING_DIM, mask_zero=True)
dec_outputs, _, _ = LSTM(LATENT_DIM, return_sequences=True, return_state=True)(
    dec_emb_layer(decoder_inputs), initial_state=encoder_states
)
decoder_dense = Dense(VOCAB_SIZE, activation='softmax')
decoder_outputs = decoder_dense(dec_outputs)

model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Out:
# E0000 00:00:1774263782.646472   92724 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %% [markdown]
# ## 🚀 3. Entraînement et Sauvegarde

# %%
model.fit([X_train, d_in_train], d_out_train, batch_size=64, epochs=100, validation_data=([X_test, d_in_test], d_out_test))

model.save('malagasy_morpheme_model_tagged.keras')


with open('vocab_data.pkl', 'wb') as f:
    pickle.dump({'char2idx': char2idx, 'idx2char': idx2char, 'MAX_LEN_IN': MAX_LEN_IN, 'MAX_LEN_OUT': MAX_LEN_OUT}, f)
print("Sauvegarde terminée ! ✅")
# Out:
# Epoch 1/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 40s 76ms/step - accuracy: 0.7758 - loss: 0.7257 - val_accuracy: 0.8538 - val_loss: 0.4722
# Epoch 2/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 42s 80ms/step - accuracy: 0.9007 - loss: 0.3254 - val_accuracy: 0.9293 - val_loss: 0.2302
# Epoch 3/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 42s 79ms/step - accuracy: 0.9455 - loss: 0.1775 - val_accuracy: 0.9535 - val_loss: 0.1499
# Epoch 4/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 43s 80ms/step - accuracy: 0.9606 - loss: 0.1252 - val_accuracy: 0.9620 - val_loss: 0.1199
# Epoch 5/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 43s 81ms/step - accuracy: 0.9686 - loss: 0.0985 - val_accuracy: 0.9673 - val_loss: 0.0991
# Epoch 6/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 43s 81ms/step - accuracy: 0.9737 - loss: 0.0809 - val_accuracy: 0.9705 - val_loss: 0.0914
# Epoch 7/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 43s 81ms/step - accuracy: 0.9769 - loss: 0.0698 - val_accuracy: 0.9724 - val_loss: 0.0852
# Epoch 8/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 43s 82ms/step - accuracy: 0.9803 - loss: 0.0592 - val_accuracy: 0.9730 - val_loss: 0.0794
# Epoch 9/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 83ms/step - accuracy: 0.9829 - loss: 0.0518 - val_accuracy: 0.9758 - val_loss: 0.0723
# Epoch 10/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 43s 81ms/step - accuracy: 0.9852 - loss: 0.0448 - val_accuracy: 0.9757 - val_loss: 0.0728
# Epoch 11/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 43s 82ms/step - accuracy: 0.9868 - loss: 0.0402 - val_accuracy: 0.9766 - val_loss: 0.0715
# Epoch 12/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 43s 82ms/step - accuracy: 0.9885 - loss: 0.0350 - val_accuracy: 0.9783 - val_loss: 0.0663
# Epoch 13/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 43s 81ms/step - accuracy: 0.9903 - loss: 0.0298 - val_accuracy: 0.9802 - val_loss: 0.0631
# Epoch 14/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 83ms/step - accuracy: 0.9917 - loss: 0.0260 - val_accuracy: 0.9803 - val_loss: 0.0626
# Epoch 15/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 82ms/step - accuracy: 0.9929 - loss: 0.0226 - val_accuracy: 0.9804 - val_loss: 0.0621
# Epoch 16/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 84ms/step - accuracy: 0.9939 - loss: 0.0199 - val_accuracy: 0.9819 - val_loss: 0.0599
# Epoch 17/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 83ms/step - accuracy: 0.9946 - loss: 0.0179 - val_accuracy: 0.9802 - val_loss: 0.0647
# Epoch 18/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 84ms/step - accuracy: 0.9958 - loss: 0.0144 - val_accuracy: 0.9817 - val_loss: 0.0617
# Epoch 19/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 83ms/step - accuracy: 0.9957 - loss: 0.0145 - val_accuracy: 0.9824 - val_loss: 0.0615
# Epoch 20/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 83ms/step - accuracy: 0.9967 - loss: 0.0116 - val_accuracy: 0.9829 - val_loss: 0.0603
# Epoch 21/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 84ms/step - accuracy: 0.9970 - loss: 0.0107 - val_accuracy: 0.9821 - val_loss: 0.0633
# Epoch 22/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 83ms/step - accuracy: 0.9967 - loss: 0.0116 - val_accuracy: 0.9828 - val_loss: 0.0644
# Epoch 23/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 45s 84ms/step - accuracy: 0.9979 - loss: 0.0082 - val_accuracy: 0.9847 - val_loss: 0.0562
# Epoch 24/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 83ms/step - accuracy: 0.9978 - loss: 0.0082 - val_accuracy: 0.9833 - val_loss: 0.0638
# Epoch 25/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 83ms/step - accuracy: 0.9971 - loss: 0.0099 - val_accuracy: 0.9823 - val_loss: 0.0664
# Epoch 26/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 83ms/step - accuracy: 0.9975 - loss: 0.0086 - val_accuracy: 0.9836 - val_loss: 0.0660
# Epoch 27/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 43s 82ms/step - accuracy: 0.9979 - loss: 0.0073 - val_accuracy: 0.9834 - val_loss: 0.0644
# Epoch 28/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 45s 85ms/step - accuracy: 0.9983 - loss: 0.0064 - val_accuracy: 0.9843 - val_loss: 0.0631
# Epoch 29/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 84ms/step - accuracy: 0.9984 - loss: 0.0059 - val_accuracy: 0.9838 - val_loss: 0.0654
# Epoch 30/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 83ms/step - accuracy: 0.9977 - loss: 0.0078 - val_accuracy: 0.9843 - val_loss: 0.0662
# Epoch 31/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 84ms/step - accuracy: 0.9979 - loss: 0.0072 - val_accuracy: 0.9843 - val_loss: 0.0627
# Epoch 32/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 82ms/step - accuracy: 0.9986 - loss: 0.0052 - val_accuracy: 0.9848 - val_loss: 0.0647
# Epoch 33/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 83ms/step - accuracy: 0.9985 - loss: 0.0053 - val_accuracy: 0.9836 - val_loss: 0.0690
# Epoch 34/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 83ms/step - accuracy: 0.9980 - loss: 0.0068 - val_accuracy: 0.9849 - val_loss: 0.0637
# Epoch 35/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 45s 84ms/step - accuracy: 0.9983 - loss: 0.0061 - val_accuracy: 0.9843 - val_loss: 0.0682
# Epoch 36/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 84ms/step - accuracy: 0.9983 - loss: 0.0059 - val_accuracy: 0.9848 - val_loss: 0.0649
# Epoch 37/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 83ms/step - accuracy: 0.9985 - loss: 0.0053 - val_accuracy: 0.9855 - val_loss: 0.0648
# Epoch 38/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 82ms/step - accuracy: 0.9991 - loss: 0.0036 - val_accuracy: 0.9860 - val_loss: 0.0651
# Epoch 39/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 83ms/step - accuracy: 0.9986 - loss: 0.0049 - val_accuracy: 0.9838 - val_loss: 0.0733
# Epoch 40/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 83ms/step - accuracy: 0.9976 - loss: 0.0077 - val_accuracy: 0.9848 - val_loss: 0.0672
# Epoch 41/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 83ms/step - accuracy: 0.9989 - loss: 0.0042 - val_accuracy: 0.9867 - val_loss: 0.0638
# Epoch 42/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 45s 85ms/step - accuracy: 0.9987 - loss: 0.0046 - val_accuracy: 0.9853 - val_loss: 0.0665
# Epoch 43/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 83ms/step - accuracy: 0.9985 - loss: 0.0052 - val_accuracy: 0.9849 - val_loss: 0.0701
# Epoch 44/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 83ms/step - accuracy: 0.9985 - loss: 0.0050 - val_accuracy: 0.9860 - val_loss: 0.0659
# Epoch 45/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 83ms/step - accuracy: 0.9987 - loss: 0.0047 - val_accuracy: 0.9855 - val_loss: 0.0638
# Epoch 46/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 83ms/step - accuracy: 0.9987 - loss: 0.0045 - val_accuracy: 0.9858 - val_loss: 0.0688
# Epoch 47/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 83ms/step - accuracy: 0.9987 - loss: 0.0046 - val_accuracy: 0.9852 - val_loss: 0.0703
# Epoch 48/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 45s 84ms/step - accuracy: 0.9988 - loss: 0.0040 - val_accuracy: 0.9855 - val_loss: 0.0676
# Epoch 49/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 45s 84ms/step - accuracy: 0.9990 - loss: 0.0036 - val_accuracy: 0.9861 - val_loss: 0.0653
# Epoch 50/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 83ms/step - accuracy: 0.9985 - loss: 0.0050 - val_accuracy: 0.9848 - val_loss: 0.0692
# Epoch 51/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 83ms/step - accuracy: 0.9986 - loss: 0.0045 - val_accuracy: 0.9850 - val_loss: 0.0700
# Epoch 52/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 83ms/step - accuracy: 0.9986 - loss: 0.0048 - val_accuracy: 0.9852 - val_loss: 0.0701
# Epoch 53/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 83ms/step - accuracy: 0.9986 - loss: 0.0045 - val_accuracy: 0.9849 - val_loss: 0.0698
# Epoch 54/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 82ms/step - accuracy: 0.9989 - loss: 0.0038 - val_accuracy: 0.9861 - val_loss: 0.0659
# Epoch 55/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 45s 84ms/step - accuracy: 0.9990 - loss: 0.0035 - val_accuracy: 0.9856 - val_loss: 0.0688
# Epoch 56/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 82ms/step - accuracy: 0.9991 - loss: 0.0030 - val_accuracy: 0.9864 - val_loss: 0.0673
# Epoch 57/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 45s 84ms/step - accuracy: 0.9988 - loss: 0.0039 - val_accuracy: 0.9854 - val_loss: 0.0683
# Epoch 58/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 83ms/step - accuracy: 0.9986 - loss: 0.0046 - val_accuracy: 0.9853 - val_loss: 0.0725
# Epoch 59/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 83ms/step - accuracy: 0.9985 - loss: 0.0051 - val_accuracy: 0.9854 - val_loss: 0.0704
# Epoch 60/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 84ms/step - accuracy: 0.9987 - loss: 0.0042 - val_accuracy: 0.9855 - val_loss: 0.0704
# Epoch 61/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 83ms/step - accuracy: 0.9993 - loss: 0.0026 - val_accuracy: 0.9870 - val_loss: 0.0644
# Epoch 62/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 45s 85ms/step - accuracy: 0.9994 - loss: 0.0024 - val_accuracy: 0.9870 - val_loss: 0.0672
# Epoch 63/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 45s 84ms/step - accuracy: 0.9985 - loss: 0.0044 - val_accuracy: 0.9845 - val_loss: 0.0725
# Epoch 64/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 83ms/step - accuracy: 0.9983 - loss: 0.0054 - val_accuracy: 0.9858 - val_loss: 0.0714
# Epoch 65/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 83ms/step - accuracy: 0.9988 - loss: 0.0038 - val_accuracy: 0.9855 - val_loss: 0.0686
# Epoch 66/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 84ms/step - accuracy: 0.9992 - loss: 0.0026 - val_accuracy: 0.9865 - val_loss: 0.0679
# Epoch 67/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 43s 82ms/step - accuracy: 0.9993 - loss: 0.0026 - val_accuracy: 0.9860 - val_loss: 0.0717
# Epoch 68/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 83ms/step - accuracy: 0.9985 - loss: 0.0049 - val_accuracy: 0.9852 - val_loss: 0.0714
# Epoch 69/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 45s 85ms/step - accuracy: 0.9986 - loss: 0.0044 - val_accuracy: 0.9855 - val_loss: 0.0684
# Epoch 70/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 83ms/step - accuracy: 0.9989 - loss: 0.0034 - val_accuracy: 0.9860 - val_loss: 0.0700
# Epoch 71/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 84ms/step - accuracy: 0.9992 - loss: 0.0026 - val_accuracy: 0.9860 - val_loss: 0.0709
# Epoch 72/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 82ms/step - accuracy: 0.9989 - loss: 0.0035 - val_accuracy: 0.9860 - val_loss: 0.0734
# Epoch 73/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 82ms/step - accuracy: 0.9986 - loss: 0.0045 - val_accuracy: 0.9853 - val_loss: 0.0737
# Epoch 74/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 83ms/step - accuracy: 0.9989 - loss: 0.0034 - val_accuracy: 0.9864 - val_loss: 0.0707
# Epoch 75/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 83ms/step - accuracy: 0.9992 - loss: 0.0028 - val_accuracy: 0.9864 - val_loss: 0.0700
# Epoch 76/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 45s 85ms/step - accuracy: 0.9992 - loss: 0.0027 - val_accuracy: 0.9865 - val_loss: 0.0727
# Epoch 77/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 45s 84ms/step - accuracy: 0.9992 - loss: 0.0029 - val_accuracy: 0.9864 - val_loss: 0.0736
# Epoch 78/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 45s 84ms/step - accuracy: 0.9989 - loss: 0.0035 - val_accuracy: 0.9864 - val_loss: 0.0721
# Epoch 79/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 83ms/step - accuracy: 0.9985 - loss: 0.0044 - val_accuracy: 0.9852 - val_loss: 0.0743
# Epoch 80/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 83ms/step - accuracy: 0.9990 - loss: 0.0033 - val_accuracy: 0.9861 - val_loss: 0.0749
# Epoch 81/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 84ms/step - accuracy: 0.9991 - loss: 0.0030 - val_accuracy: 0.9864 - val_loss: 0.0722
# Epoch 82/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 83ms/step - accuracy: 0.9989 - loss: 0.0034 - val_accuracy: 0.9866 - val_loss: 0.0699
# Epoch 83/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 83ms/step - accuracy: 0.9991 - loss: 0.0028 - val_accuracy: 0.9866 - val_loss: 0.0702
# Epoch 84/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 45s 85ms/step - accuracy: 0.9993 - loss: 0.0023 - val_accuracy: 0.9870 - val_loss: 0.0697
# Epoch 85/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 83ms/step - accuracy: 0.9991 - loss: 0.0031 - val_accuracy: 0.9853 - val_loss: 0.0760
# Epoch 86/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 84ms/step - accuracy: 0.9985 - loss: 0.0049 - val_accuracy: 0.9853 - val_loss: 0.0743
# Epoch 87/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 83ms/step - accuracy: 0.9988 - loss: 0.0037 - val_accuracy: 0.9862 - val_loss: 0.0718
# Epoch 88/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 84ms/step - accuracy: 0.9991 - loss: 0.0029 - val_accuracy: 0.9869 - val_loss: 0.0695
# Epoch 89/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 45s 85ms/step - accuracy: 0.9994 - loss: 0.0020 - val_accuracy: 0.9874 - val_loss: 0.0697
# Epoch 90/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 84ms/step - accuracy: 0.9994 - loss: 0.0020 - val_accuracy: 0.9873 - val_loss: 0.0691
# Epoch 91/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 45s 84ms/step - accuracy: 0.9988 - loss: 0.0037 - val_accuracy: 0.9858 - val_loss: 0.0755
# Epoch 92/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 83ms/step - accuracy: 0.9982 - loss: 0.0054 - val_accuracy: 0.9866 - val_loss: 0.0723
# Epoch 93/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 83ms/step - accuracy: 0.9990 - loss: 0.0031 - val_accuracy: 0.9869 - val_loss: 0.0720
# Epoch 94/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 84ms/step - accuracy: 0.9993 - loss: 0.0021 - val_accuracy: 0.9868 - val_loss: 0.0706
# Epoch 95/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 83ms/step - accuracy: 0.9994 - loss: 0.0019 - val_accuracy: 0.9873 - val_loss: 0.0702
# Epoch 96/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 45s 85ms/step - accuracy: 0.9994 - loss: 0.0020 - val_accuracy: 0.9872 - val_loss: 0.0716
# Epoch 97/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 84ms/step - accuracy: 0.9988 - loss: 0.0037 - val_accuracy: 0.9851 - val_loss: 0.0787
# Epoch 98/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 82ms/step - accuracy: 0.9984 - loss: 0.0049 - val_accuracy: 0.9864 - val_loss: 0.0739
# Epoch 99/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 45s 84ms/step - accuracy: 0.9991 - loss: 0.0026 - val_accuracy: 0.9875 - val_loss: 0.0686
# Epoch 100/100
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 44s 83ms/step - accuracy: 0.9993 - loss: 0.0019 - val_accuracy: 0.9876 - val_loss: 0.0714
# Sauvegarde terminée ! ✅

# %% [markdown]
# ## 🧪 4. Inférence (Test avec racines)

# %%
import tensorflow as tf
import numpy as np

# ── 1. Charger le modèle complet ──────────────────────────────────────────────
model_saved = tf.keras.models.load_model('malagasy_morpheme_model_tagged.keras')

# Inspecter les couches pour retrouver les bons noms
for i, layer in enumerate(model_saved.layers):
    print(f"[{i}] {layer.name} — {type(layer).__name__}")
# Out:
# [0] input_layer_2 — InputLayer
# [1] input_layer_3 — InputLayer
# [2] embedding_2 — Embedding
# [3] embedding_3 — Embedding
# [4] lstm_2 — LSTM
# [5] lstm_3 — LSTM
# [6] dense_1 — Dense

# %%
def predict(word):
    # Vectorisation du mot
    input_seq = [[char2idx.get(char, 0) for char in str(word).lower()]]
    input_seq = tf.keras.preprocessing.sequence.pad_sequences(
        input_seq, maxlen=MAX_LEN_IN, padding='post'
    )
    
    # Encodeur → états [h, c]
    states = encoder_model.predict(input_seq, verbose=0)
    
    # Initialisation décodeur avec <SOS>
    target = np.zeros((1, 1))
    target[0, 0] = char2idx['<SOS>']
    
    result = ""
    for _ in range(MAX_LEN_OUT):
        tokens, h, c = decoder_model.predict(
            [target, states[0], states[1]], verbose=0
        )
        
        idx  = np.argmax(tokens[0, -1, :])
        char = idx2char[idx]
        
        if char == '<EOS>':
            break
        
        result += char
        target[0, 0] = idx
        states = [h, c]
    
    return result.replace("|", " - ")

# %%
# ── 2. Reconstruire encoder_model ────────────────────────────────────────────
encoder_inputs = model_saved.input[0]  # input_layer_2

encoder_lstm = model_saved.get_layer('lstm_2')
encoder_output = encoder_lstm(model_saved.get_layer('embedding_2').output)

# On récupère uniquement les états [h, c], pas la séquence
state_h = encoder_lstm.output[1]
state_c = encoder_lstm.output[2]

encoder_model = tf.keras.Model(
    inputs=encoder_inputs,
    outputs=[state_h, state_c]
)

# ── 3. Reconstruire decoder_model ────────────────────────────────────────────
decoder_inputs = model_saved.input[1]  # input_layer_3

# On récupère la taille du LSTM depuis les poids directement
LSTM_UNITS = model_saved.get_layer('lstm_2').output[1].shape[-1]
print(f"LSTM units détectés : {LSTM_UNITS}")

decoder_state_input_h = tf.keras.Input(shape=(LSTM_UNITS,), name='input_h')
decoder_state_input_c = tf.keras.Input(shape=(LSTM_UNITS,), name='input_c')
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]

decoder_lstm  = model_saved.get_layer('lstm_3')
decoder_embed = model_saved.get_layer('embedding_3')

dec_emb = decoder_embed(decoder_inputs)
dec_out, dec_h, dec_c = decoder_lstm(
    dec_emb,
    initial_state=decoder_states_inputs
)

decoder_dense   = model_saved.get_layer('dense_1')
decoder_outputs = decoder_dense(dec_out)

decoder_model = tf.keras.Model(
    inputs=[decoder_inputs] + decoder_states_inputs,
    outputs=[decoder_outputs, dec_h, dec_c]
)

# On définit manuellement la liste des mots à tester
test_samples = ["miaboabo", "fahatany", "homady", "akasy", "mahakasy"]


print("✅ encoder_model et decoder_model reconstruits !")

# ── 4. Test rapide ────────────────────────────────────────────────────────────
for word in test_samples:
    res = predict(word)
    print(f"🔹 {word} ➔ {res}")
# Out:
# LSTM units détectés : 256
# ✅ encoder_model et decoder_model reconstruits !
# 🔹 miaboabo ➔ mi - [abo] - [abo]
# 🔹 fahatany ➔ faha - [tany]
# 🔹 homady ➔ hom - hady
# 🔹 akasy ➔ a - [kasy]
# 🔹 mahakasy ➔ maha - [kasy]

# %%
## 📊 CELLULE STATS — Dashboard Malagasy (pandas + matplotlib uniquement)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

plt.rcParams.update({
    'figure.facecolor':  '#0f1117',
    'axes.facecolor':    '#1a1a2e',
    'axes.edgecolor':    '#2a2a4a',
    'axes.labelcolor':   '#f0ede8',
    'xtick.color':       '#6a7a9a',
    'ytick.color':       '#6a7a9a',
    'text.color':        '#f0ede8',
    'grid.color':        '#2a2a4a',
    'grid.linewidth':    0.5,
    'font.family':       'monospace',
})

# ════════════════════════════════════════════════════════════════════════════
# 1. ARCHITECTURE DU MODÈLE
# ════════════════════════════════════════════════════════════════════════════
print("=" * 55)
print("  🇲🇬  MALAGASY MORPHÈME — STATISTIQUES DU MODÈLE")
print("=" * 55)

rows = []
for layer in model_saved.layers:
    try:
        params = layer.count_params()
    except:
        params = 0
    try:
        shape = str(layer.output_shape)
    except AttributeError:
        shape = 'N/A'
    rows.append({
        'Couche'      : layer.name,
        'Type'        : type(layer).__name__,
        'Output Shape': shape,
        'Paramètres'  : params,
    })

df_arch = pd.DataFrame(rows)
df_arch.index += 1

print("\n📐 Architecture du modèle\n")
print(df_arch.to_string())
print(f"\n  Total paramètres : {model_saved.count_params():,}")
print(f"  Couches          : {len(model_saved.layers)}")


# ════════════════════════════════════════════════════════════════════════════
# 2. VOCABULAIRE
# ════════════════════════════════════════════════════════════════════════════
if 'char2idx' in globals():
    print("\n" + "=" * 55)
    print("  🔤  VOCABULAIRE")
    print("=" * 55)

    special = [c for c in char2idx if c in ['<SOS>', '<EOS>', '<PAD>']]
    chars   = sorted([c for c in char2idx if c not in special])

    df_vocab = pd.DataFrame([
        {'Métrique': 'Tokens total',        'Valeur': len(char2idx)},
        {'Métrique': 'Caractères uniques',  'Valeur': len(chars)},
        {'Métrique': 'Tokens spéciaux',     'Valeur': len(special)},
        {'Métrique': 'Longueur max entrée', 'Valeur': MAX_LEN_IN  if 'MAX_LEN_IN'  in globals() else 'N/A'},
        {'Métrique': 'Longueur max sortie', 'Valeur': MAX_LEN_OUT if 'MAX_LEN_OUT' in globals() else 'N/A'},
    ])
    df_vocab.index += 1

    print("\n")
    print(df_vocab.to_string())
    print(f"\n  Tokens spéciaux : {', '.join(special)}")
    print(f"  Caractères      : {' '.join(chars)}")

    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    fig.suptitle('Vocabulaire', color='#e8b96a', fontsize=12)

    lengths = [len(c) for c in char2idx.keys()]
    axes[0].hist(lengths, bins=range(1, max(lengths)+2),
                 color='#6a9ee8', edgecolor='#2a2a4a', align='left')
    axes[0].set_title('Distribution longueur des tokens', color='#f0ede8')
    axes[0].set_xlabel('Longueur')
    axes[0].set_ylabel('Nombre de tokens')
    axes[0].grid(True, alpha=0.3)

    labels = ['Caractères\nnormaux', 'Tokens\nspéciaux']
    sizes  = [len(chars), len(special)]
    axes[1].bar(labels, sizes, color=['#6a9ee8', '#e8b96a'], edgecolor='#2a2a4a', width=0.4)
    axes[1].set_title('Répartition du vocabulaire', color='#f0ede8')
    axes[1].set_ylabel('Nombre de tokens')
    axes[1].grid(True, alpha=0.3, axis='y')
    for i, v in enumerate(sizes):
        axes[1].text(i, v + 0.1, str(v), ha='center', color='#f0ede8', fontsize=11)

    plt.tight_layout()
    plt.show()


# ════════════════════════════════════════════════════════════════════════════
# 3. COURBES D'ENTRAÎNEMENT
# ════════════════════════════════════════════════════════════════════════════

# Détection robuste du format history
def _parse_history(h):
    if hasattr(h, 'history'):
        hist = h.history
    elif isinstance(h, dict):
        hist = h
    else:
        hist = {}
    return hist if 'loss' in hist and len(hist['loss']) > 0 else None

hist = _parse_history(history) if 'history' in globals() else None

if hist:
    print("\n" + "=" * 55)
    print("  📈  COURBES D'ENTRAÎNEMENT")
    print("=" * 55)

    epochs  = range(1, len(hist['loss']) + 1)
    df_hist = pd.DataFrame({'Époque': list(epochs), 'Loss': hist['loss']})

    if 'val_loss' in hist:
        df_hist['Val Loss'] = hist['val_loss']

    acc_key = next((k for k in ['accuracy', 'sparse_categorical_accuracy'] if k in hist), None)
    if acc_key:
        df_hist['Accuracy']     = hist[acc_key]
        df_hist['Val Accuracy'] = hist[f'val_{acc_key}']

    df_hist = df_hist.set_index('Époque')
    print("\n")
    print(df_hist.round(4).to_string())

    if 'Val Loss' in df_hist:
        best_epoch = df_hist['Val Loss'].idxmin()
        print(f"\n  ✅ Meilleur epoch : {best_epoch}  |  Val Loss : {df_hist.loc[best_epoch,'Val Loss']:.4f}")

    n_plots = 2 if acc_key else 1
    fig, axes = plt.subplots(1, n_plots, figsize=(12 if n_plots == 2 else 6, 4))
    if n_plots == 1:
        axes = [axes]

    fig.suptitle("Courbes d'entraînement", color='#e8b96a', fontsize=12)

    axes[0].plot(list(epochs), hist['loss'],     color='#e8b96a', linewidth=2, label='Train loss')
    if 'val_loss' in hist:
        axes[0].plot(list(epochs), hist['val_loss'], color='#6a9ee8', linewidth=2,
                     linestyle='--', label='Val loss')
        axes[0].fill_between(list(epochs), hist['val_loss'], alpha=0.08, color='#6a9ee8')
        if 'Val Loss' in df_hist:
            axes[0].axvline(x=best_epoch, color='#6ae8a0', linewidth=1, linestyle=':')
    axes[0].fill_between(list(epochs), hist['loss'], alpha=0.08, color='#e8b96a')
    axes[0].set_title('Loss', color='#f0ede8')
    axes[0].set_xlabel('Époque')
    axes[0].set_ylabel('Loss')
    axes[0].legend()
    axes[0].grid(True, alpha=0.3)

    if acc_key:
        axes[1].plot(list(epochs), hist[acc_key],          color='#e8b96a', linewidth=2, label='Train acc')
        axes[1].plot(list(epochs), hist[f'val_{acc_key}'], color='#6a9ee8', linewidth=2,
                     linestyle='--', label='Val acc')
        axes[1].fill_between(list(epochs), hist[acc_key],          alpha=0.08, color='#e8b96a')
        axes[1].fill_between(list(epochs), hist[f'val_{acc_key}'], alpha=0.08, color='#6a9ee8')
        axes[1].set_title('Accuracy', color='#f0ede8')
        axes[1].set_xlabel('Époque')
        axes[1].set_ylabel('Accuracy')
        axes[1].set_ylim(0, 1.05)
        axes[1].legend()
        axes[1].grid(True, alpha=0.3)

    plt.tight_layout()
    plt.show()

else:
    print("\n  ⚠️  history vide ou non disponible — relance model.fit() avec : history = model.fit(...)")


# ════════════════════════════════════════════════════════════════════════════
# 4. EXEMPLES DE PRÉDICTIONS
# ════════════════════════════════════════════════════════════════════════════
if 'predict' in globals():
    print("\n" + "=" * 55)
    print("  🔍  EXEMPLES DE PRÉDICTIONS")
    print("=" * 55)

    samples = test_samples if 'test_samples' in globals() else \
              ["miaboabo", "fahatany", "homady", "akasy", "mahakasy"]

    rows = []
    for word in samples:
        try:
            res = predict(word)
            rows.append({'Mot': word, 'Morphèmes prédits': res, 'Statut': '✅'})
        except Exception as e:
            rows.append({'Mot': word, 'Morphèmes prédits': str(e), 'Statut': '❌'})

    df_pred = pd.DataFrame(rows)
    df_pred.index += 1
    print("\n")
    print(df_pred.to_string())

print("\n" + "=" * 55)
print("  Fin du dashboard")
print("=" * 55)
# Out:
# =======================================================
#   🇲🇬  MALAGASY MORPHÈME — STATISTIQUES DU MODÈLE
# =======================================================
#
# 📐 Architecture du modèle
#
#           Couche        Type Output Shape  Paramètres
# 1  input_layer_2  InputLayer          N/A           0
# 2  input_layer_3  InputLayer          N/A           0
# 3    embedding_2   Embedding          N/A        1856
# 4    embedding_3   Embedding          N/A        1856
# 5         lstm_2        LSTM          N/A      328704
# 6         lstm_3        LSTM          N/A      328704
# 7        dense_1       Dense          N/A        7453
#
#   Total paramètres : 668,573
#   Couches          : 7
#
# =======================================================
#   🔤  VOCABULAIRE
# =======================================================
#
#
#               Métrique  Valeur
# 1         Tokens total      29
# 2   Caractères uniques      26
# 3      Tokens spéciaux       3
# 4  Longueur max entrée      22
# 5  Longueur max sortie      32
#
#   Tokens spéciaux : <PAD>, <SOS>, <EOS>
#   Caractères      : " [ ] a b d e f g h i j k l m n o p r s t v y z | ỳ
#   ⚠️  history vide ou non disponible — relance model.fit() avec : history = model.fit(...)
#
# =======================================================
#   🔍  EXEMPLES DE PRÉDICTIONS
# =======================================================
#
#
#         Mot   Morphèmes prédits Statut
# 1  miaboabo  mi - [abo] - [abo]      ✅
# 2  fahatany       faha - [tany]      ✅
# 3    homady          hom - hady      ✅
# 4     akasy          a - [kasy]      ✅
# 5  mahakasy       maha - [kasy]      ✅
#
# =======================================================
#   Fin du dashboard
# =======================================================

# %%
## 🇲🇬 CELLULE GUI — Interface Malagasy Morphème Predictor
## Colle ce code dans une nouvelle cellule et exécute-la

import ipywidgets as widgets
from IPython.display import display, HTML, clear_output

# ── Styles CSS injectés ──────────────────────────────────────────────────────
display(HTML("""
<style>
@import url('https://fonts.googleapis.com/css2?family=DM+Mono:wght@400;500&family=Playfair+Display:wght@700&display=swap');

.mg-card {
    background: linear-gradient(135deg, #0f1117 0%, #1a1a2e 100%);
    border: 1px solid #2a2a4a;
    border-radius: 16px;
    padding: 2rem 2.5rem;
    max-width: 600px;
    margin: 1rem auto;
    font-family: 'DM Mono', monospace;
    box-shadow: 0 8px 40px rgba(106,158,232,0.08), 0 0 0 1px rgba(232,185,106,0.05);
}

.mg-title {
    font-family: 'Playfair Display', serif;
    font-size: 1.6rem;
    color: #e8b96a;
    text-align: center;
    margin-bottom: 0.3rem;
    letter-spacing: 0.02em;
}

.mg-subtitle {
    text-align: center;
    color: #6a7a9a;
    font-size: 0.75rem;
    margin-bottom: 1.8rem;
    letter-spacing: 0.1em;
    text-transform: uppercase;
}

.mg-result-box {
    background: #0a0a12;
    border: 1px solid #2a2a4a;
    border-left: 3px solid #e8b96a;
    border-radius: 10px;
    padding: 1.2rem 1.5rem;
    margin-top: 1.5rem;
    font-family: 'DM Mono', monospace;
}

.mg-result-label {
    font-size: 0.65rem;
    color: #6a7a9a;
    text-transform: uppercase;
    letter-spacing: 0.12em;
    margin-bottom: 0.5rem;
}

.mg-result-word {
    font-size: 1rem;
    color: #a0b4d0;
    margin-bottom: 0.3rem;
}

.mg-result-arrow {
    color: #e8b96a;
    margin: 0 0.5rem;
}

.mg-result-morpheme {
    font-size: 1.2rem;
    color: #e8f4ff;
    font-weight: 500;
    letter-spacing: 0.05em;
}

.mg-history-item {
    display: flex;
    align-items: center;
    gap: 0.5rem;
    padding: 0.5rem 0;
    border-bottom: 1px solid #1a1a2e;
    font-size: 0.85rem;
}

.mg-history-item:last-child { border-bottom: none; }

.mg-error {
    border-left-color: #e86a6a !important;
}

.mg-error .mg-result-morpheme {
    color: #e86a6a;
}

.mg-badge {
    display: inline-block;
    background: rgba(232,185,106,0.12);
    color: #e8b96a;
    border-radius: 4px;
    padding: 0.1rem 0.5rem;
    font-size: 0.7rem;
    letter-spacing: 0.08em;
}
</style>
"""))

# ── En-tête ──────────────────────────────────────────────────────────────────
display(HTML("""
<div class="mg-card">
    <div class="mg-title">🇲🇬 Analyseur Morphologique</div>
    <div class="mg-subtitle">Malagasy · Seq2Seq · Prédiction de morphèmes</div>
</div>
"""))

# ── Widgets ──────────────────────────────────────────────────────────────────
input_word = widgets.Text(
    placeholder='Ex: miaboabo, fahatany, mahakasy...',
    layout=widgets.Layout(width='100%', height='42px'),
    style={'font_size': '14px'}
)

btn_predict = widgets.Button(
    description='Analyser ➔',
    button_style='',
    layout=widgets.Layout(width='140px', height='42px'),
    style={'button_color': '#1a1a2e', 'font_weight': 'bold'}
)

btn_clear = widgets.Button(
    description='Effacer',
    button_style='',
    layout=widgets.Layout(width='100px', height='42px'),
    style={'button_color': '#0a0a12'}
)

# Zone de résultat principal
output_main = widgets.Output()

# Zone historique
output_history = widgets.Output()

# Historique stocké en mémoire
history = []

# ── Logique ──────────────────────────────────────────────────────────────────
def on_predict(b):
    word = input_word.value.strip()
    if not word:
        return

    with output_main:
        clear_output(wait=True)
        display(HTML('<div class="mg-result-box"><div class="mg-result-label">Traitement...</div></div>'))

    try:
        result = predict(word)   # ← appel à ta fonction predict() existante
        is_error = False
    except Exception as e:
        result = f"Erreur : {e}"
        is_error = True

    error_class = "mg-error" if is_error else ""

    with output_main:
        clear_output(wait=True)
        display(HTML(f"""
        <div class="mg-card" style="margin-top:0">
            <div class="mg-result-box {error_class}">
                <div class="mg-result-label">Résultat</div>
                <div>
                    <span class="mg-result-word">{word}</span>
                    <span class="mg-result-arrow">➔</span>
                    <span class="mg-result-morpheme">{result}</span>
                </div>
            </div>
        </div>
        """))

    # Ajouter à l'historique
    if not is_error:
        history.insert(0, (word, result))
        if len(history) > 8:
            history.pop()

        with output_history:
            clear_output(wait=True)
            items_html = "".join([
                f'<div class="mg-history-item">'
                f'<span style="color:#6a9ee8">{w}</span>'
                f'<span style="color:#e8b96a;margin:0 6px">➔</span>'
                f'<span style="color:#e0e0f0">{r}</span>'
                f'</div>'
                for w, r in history
            ])
            display(HTML(f"""
            <div class="mg-card" style="margin-top:0">
                <div style="font-size:0.7rem;color:#6a7a9a;text-transform:uppercase;
                            letter-spacing:0.1em;margin-bottom:1rem">
                    Historique <span class="mg-badge">{len(history)}</span>
                </div>
                {items_html}
            </div>
            """))

def on_clear(b):
    input_word.value = ''
    history.clear()
    with output_main:
        clear_output()
    with output_history:
        clear_output()

# Permettre validation avec Entrée
def on_enter(widget):
    on_predict(None)

btn_predict.on_click(on_predict)
btn_clear.on_click(on_clear)
input_word.on_submit(on_enter)

# ── Layout final ─────────────────────────────────────────────────────────────
row = widgets.HBox(
    [input_word, btn_predict, btn_clear],
    layout=widgets.Layout(gap='8px', width='100%', max_width='600px', margin='0 auto')
)

display(widgets.VBox(
    [row, output_main, output_history],
    layout=widgets.Layout(width='100%', max_width='620px', margin='0 auto', gap='4px')
))
# Out:
# <style>
# @import url('https://fonts.googleapis.com/css2?family=DM+Mono:wght@400;500&family=Playfair+Display:wght@700&display=swap');
#
# .mg-card {
#     background: linear-gradient(135deg, #0f1117 0%, #1a1a2e 100%);
#     border: 1px solid #2a2a4a;
#     border-radius: 16px;
#     padding: 2rem 2.5rem;
#     max-width: 600px;
#     margin: 1rem auto;
#     font-family: 'DM Mono', monospace;
#     box-shadow: 0 8px 40px rgba(106,158,232,0.08), 0 0 0 1px rgba(232,185,106,0.05);
# }
#
# .mg-title {
#     font-family: 'Playfair Display', serif;
#     font-size: 1.6rem;
#     color: #e8b96a;
#     text-align: center;
#     margin-bottom: 0.3rem;
#     letter-spacing: 0.02em;
# }
#
# .mg-subtitle {
#     text-align: center;
#     color: #6a7a9a;
#     font-size: 0.75rem;
#     margin-bottom: 1.8rem;
#     letter-spacing: 0.1em;
#     text-transform: uppercase;
# }
#
# .mg-result-box {
#     background: #0a0a12;
#     border: 1px solid #2a2a4a;
#     border-left: 3px solid #e8b96a;
#     border-radius: 10px;
#     padding: 1.2rem 1.5rem;
#     margin-top: 1.5rem;
#     font-family: 'DM Mono', monospace;
# }
#
# .mg-result-label {
#     font-size: 0.65rem;
#     color: #6a7a9a;
#     text-transform: uppercase;
#     letter-spacing: 0.12em;
#     margin-bottom: 0.5rem;
# }
#
# .mg-result-word {
#     font-size: 1rem;
#     color: #a0b4d0;
#     margin-bottom: 0.3rem;
# }
#
# .mg-result-arrow {
#     color: #e8b96a;
#     margin: 0 0.5rem;
# }
#
# .mg-result-morpheme {
#     font-size: 1.2rem;
#     color: #e8f4ff;
#     font-weight: 500;
#     letter-spacing: 0.05em;
# }
#
# .mg-history-item {
#     display: flex;
#     align-items: center;
#     gap: 0.5rem;
#     padding: 0.5rem 0;
#     border-bottom: 1px solid #1a1a2e;
#     font-size: 0.85rem;
# }
#
# .mg-history-item:last-child { border-bottom: none; }
#
# .mg-error {
#     border-left-color: #e86a6a !important;
# }
#
# .mg-error .mg-result-morpheme {
#     color: #e86a6a;
# }
#
# .mg-badge {
#     display: inline-block;
#     background: rgba(232,185,106,0.12);
#     color: #e8b96a;
#     border-radius: 4px;
#     padding: 0.1rem 0.5rem;
#     font-size: 0.7rem;
#     letter-spacing: 0.08em;
# }
# </style>
# <div class="mg-card">
#     <div class="mg-title">🇲🇬 Analyseur Morphologique</div>
#     <div class="mg-subtitle">Malagasy · Seq2Seq · Prédiction de morphèmes</div>
# </div>
# VBox(children=(HBox(children=(Text(value='', layout=Layout(height='42px', width='100%'), placeholder='Ex: miab…
